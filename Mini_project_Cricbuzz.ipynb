# %% [markdown]
# <a href="https://colab.research.google.com/github/devi90200/cricbuzz_project/blob/main/Mini_project_Cricbuzz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd


url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

headers = {
	"x-rapidapi-key": "5d1acd4318msh2a53e9ea9913af9p12e3f0jsn95bb880184c8",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
data=response.json()
print(response.json())
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9602, 'seriesName': 'South Africa tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 117008, 'seriesId': 9602, 'seriesName': 'South Africa tour of Australia, 2025', 'matchDesc': '1st ODI', 'matchFormat': 'ODI', 'startDate': '1755577800000', 'endDate': '1755606600000', 'state': 'Complete', 'status': 'South Africa won by 98 runs', 'team1': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'imageId': 172126}, 'team2': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 172117}, 'venueInfo': {'id': 218, 'ground': "Cazaly's Stadium", 'city': 'Cairns', 'timezone': '+10:00', 'latitude': '-16.935662', 'longitude': '145.749057'}, 'currBatTeamId': 11, 'seriesStartDt': '1754697600000', 'seriesEndDt': '1756080000000', 'isTimeAnnounced': True, 'stateTitle': 'RSA Won', 'isFantasyEnabled': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs
# ...

# %%
data
# Out:
# {'typeMatches': [{'matchType': 'International',
#    'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9602,
#       'seriesName': 'South Africa tour of Australia, 2025',
#       'matches': [{'matchInfo': {'matchId': 117008,
#          'seriesId': 9602,
#          'seriesName': 'South Africa tour of Australia, 2025',
#          'matchDesc': '1st ODI',
#          'matchFormat': 'ODI',
#          'startDate': '1755577800000',
#          'endDate': '1755606600000',
#          'state': 'Complete',
#          'status': 'South Africa won by 98 runs',
#          'team1': {'teamId': 11,
#           'teamName': 'South Africa',
#           'teamSName': 'RSA',
#           'imageId': 172126},
#          'team2': {'teamId': 4,
#           'teamName': 'Australia',
#           'teamSName': 'AUS',
#           'imageId': 172117},
#          'venueInfo': {'id': 218,
#           'ground': "Cazaly's Stadium",
#           'city': 'Cairns',
#           'timezone': '+10:00',
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['typeMatches', 'filters', 'appIndex', 'responseLastUpdated', 'contentFilters'])

# %%
data['appIndex']
# Out:
# {'seoTitle': 'Live Cricket Score - Scorecard and Match Results',
#  'webURL': 'www.cricbuzz.com/live-cricket-scores/'}

# %%
data['contentFilters']
# Out:
# [{'filterId': 'liveStream', 'filterName': 'Live Streaming'}]

# %%
data['filters']
# Out:
# {'matchType': ['International', 'League', 'Domestic', 'Women']}

# %%
data['responseLastUpdated']
# Out:
# '1755758018'

# %%
data['typeMatches']
# Out:
# [{'matchType': 'International',
#   'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9602,
#      'seriesName': 'South Africa tour of Australia, 2025',
#      'matches': [{'matchInfo': {'matchId': 117008,
#         'seriesId': 9602,
#         'seriesName': 'South Africa tour of Australia, 2025',
#         'matchDesc': '1st ODI',
#         'matchFormat': 'ODI',
#         'startDate': '1755577800000',
#         'endDate': '1755606600000',
#         'state': 'Complete',
#         'status': 'South Africa won by 98 runs',
#         'team1': {'teamId': 11,
#          'teamName': 'South Africa',
#          'teamSName': 'RSA',
#          'imageId': 172126},
#         'team2': {'teamId': 4,
#          'teamName': 'Australia',
#          'teamSName': 'AUS',
#          'imageId': 172117},
#         'venueInfo': {'id': 218,
#          'ground': "Cazaly's Stadium",
#          'city': 'Cairns',
#          'timezone': '+10:00',
#          'latitude': '-16.935662',
# ...

# %%
type_match=data['typeMatches']
print(type_match[0])
print(type_match)
# Out:
# {'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9602, 'seriesName': 'South Africa tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 117008, 'seriesId': 9602, 'seriesName': 'South Africa tour of Australia, 2025', 'matchDesc': '1st ODI', 'matchFormat': 'ODI', 'startDate': '1755577800000', 'endDate': '1755606600000', 'state': 'Complete', 'status': 'South Africa won by 98 runs', 'team1': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'imageId': 172126}, 'team2': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 172117}, 'venueInfo': {'id': 218, 'ground': "Cazaly's Stadium", 'city': 'Cairns', 'timezone': '+10:00', 'latitude': '-16.935662', 'longitude': '145.749057'}, 'currBatTeamId': 11, 'seriesStartDt': '1754697600000', 'seriesEndDt': '1756080000000', 'isTimeAnnounced': True, 'stateTitle': 'RSA Won', 'isFantasyEnabled': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 296, 'wickets'
# ...

# %%
series_match=type_match[0]['seriesMatches']
print(series_match[0])
# Out:
# {'seriesAdWrapper': {'seriesId': 9602, 'seriesName': 'South Africa tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 117008, 'seriesId': 9602, 'seriesName': 'South Africa tour of Australia, 2025', 'matchDesc': '1st ODI', 'matchFormat': 'ODI', 'startDate': '1755577800000', 'endDate': '1755606600000', 'state': 'Complete', 'status': 'South Africa won by 98 runs', 'team1': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'imageId': 172126}, 'team2': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 172117}, 'venueInfo': {'id': 218, 'ground': "Cazaly's Stadium", 'city': 'Cairns', 'timezone': '+10:00', 'latitude': '-16.935662', 'longitude': '145.749057'}, 'currBatTeamId': 11, 'seriesStartDt': '1754697600000', 'seriesEndDt': '1756080000000', 'isTimeAnnounced': True, 'stateTitle': 'RSA Won', 'isFantasyEnabled': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 296, 'wickets': 8, 'overs': 49.6}}, 'team2Score': {'inngs1': {'
# ...

# %%
series_wrapper=series_match[0]['seriesAdWrapper']
print(series_wrapper.keys())
# Out:
# dict_keys(['seriesId', 'seriesName', 'matches'])

# %%
match_list=series_wrapper['matches']
first_match = match_list[0]
print(first_match['matchInfo'])
# Out:
# {'matchId': 117008, 'seriesId': 9602, 'seriesName': 'South Africa tour of Australia, 2025', 'matchDesc': '1st ODI', 'matchFormat': 'ODI', 'startDate': '1755577800000', 'endDate': '1755606600000', 'state': 'Complete', 'status': 'South Africa won by 98 runs', 'team1': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'imageId': 172126}, 'team2': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 172117}, 'venueInfo': {'id': 218, 'ground': "Cazaly's Stadium", 'city': 'Cairns', 'timezone': '+10:00', 'latitude': '-16.935662', 'longitude': '145.749057'}, 'currBatTeamId': 11, 'seriesStartDt': '1754697600000', 'seriesEndDt': '1756080000000', 'isTimeAnnounced': True, 'stateTitle': 'RSA Won', 'isFantasyEnabled': True}

# %%
match_info=first_match['matchInfo']

print('matchId:',match_info['matchId'])
print('seriesId:',match_info['seriesId'])
print('matchDesc:',match_info['matchDesc'])
print('matchFormat:',match_info['matchFormat'])
print('startDate:',match_info['startDate'])
print('endDate:',match_info['endDate'])
print('state:',match_info['state'])
print('status:',match_info['status'])

print('Team1:',match_info['team1']['teamName'])
print('Team2:',match_info['team2']['teamName'])

print('VenueInfo:',match_info['venueInfo']['ground'])
# Out:
# matchId: 117008
# seriesId: 9602
# matchDesc: 1st ODI
# matchFormat: ODI
# startDate: 1755577800000
# endDate: 1755606600000
# state: Complete
# status: South Africa won by 98 runs
# Team1: South Africa
# Team2: Australia
# VenueInfo: Cazaly's Stadium

# %%
matches=[]

for type_match in data.get("typeMatches",[]):
  for series_match in type_match.get("seriesMatches",[]):
    series_data=series_match.get("seriesAdWrapper",{})
    series_id=series_data.get("seriesId")
    series_name=series_data.get("seriesName")

    for match in series_data.get("matches",{}):
      info=match.get("matchInfo",{})
      match_id=info.get("matchId")
      match_desc=info.get("matchDesc")
      match_format=info.get("matchFormat")
      start_date=info.get("startDate")
      status=info.get("status")
      team1=info.get("team1", {}).get("teamName")
      team2=info.get("team2", {}).get("teamName")
      venue=info.get("venueInfo", {}).get("ground")

      matches.append({
          "series_id":series_id,
          "series_name":series_name,
          "match_id":match_id,
          "match_desc":match_desc,
          "match_format":match_format,
          "team1":team1,
          "team2":team2,
          "venue":venue,
          "status":status
      })

df=pd.DataFrame(matches)
df
# Out:
#     series_id                                        series_name  match_id  \
# 0        9602               South Africa tour of Australia, 2025    117008
# 1        9602               South Africa tour of Australia, 2025    116990
# 2       10658                        Norway T20I Tri-Series 2025    131136
# 3       10658                        Norway T20I Tri-Series 2025    131141
# 4       10658                        Norway T20I Tri-Series 2025    131125
# ..        ...                                                ...       ...
# 92      10603                 Cambodia Women tour Singapore 2025    131504
# 93      10669  ICC Womens T20 World Cup Europe Qualifier Divi...    131158
# 94      10669  ICC Womens T20 World Cup Europe Qualifier Divi...    131152
# 95      10686               India A Women tour of Australia 2025    131471
# 96      10686               India A Women tour of Australia 2025    131466
#
# ...

# %%
import requests
import pandas as pd

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/rankings/batsmen"

querystring = {"formatType":"test"}

headers = {
	"x-rapidapi-key": "5d1acd4318msh2a53e9ea9913af9p12e3f0jsn95bb880184c8",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data=response.json()
print(response.json())
# Out:
# {'rank': [{'id': '8019', 'rank': '1', 'name': 'Joe Root', 'country': 'England', 'rating': '908', 'points': '908', 'lastUpdatedOn': '2025-08-23', 'trend': 'Flat', 'faceImageId': '717792', 'countryId': '9'}, {'id': '12201', 'rank': '2', 'name': 'Harry Brook', 'country': 'England', 'rating': '868', 'difference': 1, 'points': '868', 'lastUpdatedOn': '2025-08-23', 'trend': 'Up', 'faceImageId': '717793', 'countryId': '9'}, {'id': '6326', 'rank': '3', 'name': 'Kane Williamson', 'country': 'New Zealand', 'rating': '850', 'difference': -1, 'points': '850', 'lastUpdatedOn': '2025-08-23', 'trend': 'Down', 'faceImageId': '616418', 'countryId': '13'}, {'id': '2250', 'rank': '4', 'name': 'Steven Smith', 'country': 'Australia', 'rating': '816', 'points': '816', 'lastUpdatedOn': '2025-08-23', 'trend': 'Flat', 'faceImageId': '619873', 'countryId': '4'}, {'id': '13940', 'rank': '5', 'name': 'Yashasvi Jaiswal', 'country': 'India', 'rating': '792', 'points': '792', 'lastUpdatedOn': '2025-08-23', 'trend'
# ...

# %%
data
# Out:
# {'rank': [{'id': '8019',
#    'rank': '1',
#    'name': 'Joe Root',
#    'country': 'England',
#    'rating': '908',
#    'points': '908',
#    'lastUpdatedOn': '2025-08-23',
#    'trend': 'Flat',
#    'faceImageId': '717792',
#    'countryId': '9'},
#   {'id': '12201',
#    'rank': '2',
#    'name': 'Harry Brook',
#    'country': 'England',
#    'rating': '868',
#    'difference': 1,
#    'points': '868',
#    'lastUpdatedOn': '2025-08-23',
#    'trend': 'Up',
#    'faceImageId': '717793',
#    'countryId': '9'},
#   {'id': '6326',
#    'rank': '3',
#    'name': 'Kane Williamson',
#    'country': 'New Zealand',
#    'rating': '850',
#    'difference': -1,
#    'points': '850',
#    'lastUpdatedOn': '2025-08-23',
#    'trend': 'Down',
#    'faceImageId': '616418',
#    'countryId': '13'},
#   {'id': '2250',
#    'rank': '4',
#    'name': 'Steven Smith',
#    'country': 'Australia',
#    'rating': '816',
#    'points': '816',
#    'lastUpdatedOn': '2025-08-23',
#    'trend': 'Flat',
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['player'])

# %%
data['rank']
# Out:
# [{'id': '8019',
#   'rank': '1',
#   'name': 'Joe Root',
#   'country': 'England',
#   'rating': '908',
#   'points': '908',
#   'lastUpdatedOn': '2025-08-23',
#   'trend': 'Flat',
#   'faceImageId': '717792',
#   'countryId': '9'},
#  {'id': '12201',
#   'rank': '2',
#   'name': 'Harry Brook',
#   'country': 'England',
#   'rating': '868',
#   'difference': 1,
#   'points': '868',
#   'lastUpdatedOn': '2025-08-23',
#   'trend': 'Up',
#   'faceImageId': '717793',
#   'countryId': '9'},
#  {'id': '6326',
#   'rank': '3',
#   'name': 'Kane Williamson',
#   'country': 'New Zealand',
#   'rating': '850',
#   'difference': -1,
#   'points': '850',
#   'lastUpdatedOn': '2025-08-23',
#   'trend': 'Down',
#   'faceImageId': '616418',
#   'countryId': '13'},
#  {'id': '2250',
#   'rank': '4',
#   'name': 'Steven Smith',
#   'country': 'Australia',
#   'rating': '816',
#   'points': '816',
#   'lastUpdatedOn': '2025-08-23',
#   'trend': 'Flat',
#   'faceImageId': '619873',
# ...

# %%
data['appIndex']
# Out:
# {'seoTitle': 'ICC Cricket Rankings - Top 100 Batter | Cricbuzz.com',
#  'webURL': 'www.cricbuzz.com/cricket-stats/icc-rankings'}

# %%
rank_info=data['rank']
print(rank_info[0])
# Out:
# {'id': '8019', 'rank': '1', 'name': 'Joe Root', 'country': 'England', 'rating': '908', 'points': '908', 'lastUpdatedOn': '2025-08-23', 'trend': 'Flat', 'faceImageId': '717792', 'countryId': '9'}

# %%
players = data.get("rank", [])
stats = []
for p in players:
    stat = {
        "Rank": p.get("rank"),
        "Name": p.get("name"),
        "Country": p.get("country"),
        "Rating": p.get("rating")
    }
    stats.append(stat)
df = pd.DataFrame(stats)
df
# Out:
#    Rank              Name       Country Rating
# 0     1          Joe Root       England    908
# 1     2       Harry Brook       England    868
# 2     3   Kane Williamson   New Zealand    850
# 3     4      Steven Smith     Australia    816
# 4     5  Yashasvi Jaiswal         India    792
# 5     6      Temba Bavuma  South Africa    790
# 6     7    Kamindu Mendis     Sri Lanka    781
# 7     8      Rishabh Pant         India    768
# 8     9    Daryl Mitchell   New Zealand    748
# 9    10       Ben Duckett       England    747
# 10   11       Travis Head     Australia    740
# 11   12      Saud Shakeel      Pakistan    739
# 12   13      Shubman Gill         India    725
# 13   14  Dinesh Chandimal     Sri Lanka    717
# 14   15     Aiden Markram  South Africa    709

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/schedule/v1/international"

headers = {
	"x-rapidapi-key": "5d1acd4318msh2a53e9ea9913af9p12e3f0jsn95bb880184c8",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
data=response.json()
print(response.json())
# Out:
# {'matchScheduleMap': [{'scheduleAdWrapper': {'date': 'SUN, AUG 24 2025', 'matchScheduleList': [{'seriesName': 'South Africa tour of Australia, 2025', 'matchInfo': [{'matchId': 117020, 'seriesId': 9602, 'matchDesc': '3rd ODI', 'matchFormat': 'ODI', 'startDate': '1756009800000', 'endDate': '1756079999000', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'isFullMember': True, 'imageId': 172117}, 'team2': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'isFullMember': True, 'imageId': 172126}, 'venueInfo': {'ground': 'Great Barrier Reef Arena', 'city': 'Mackay', 'country': 'Australia', 'timezone': '+10:00'}, 'isFantasyHandbookEnabled': True}], 'seriesId': 9602, 'seriesCategory': 'International', 'isFantasyEnabled': True}, {'seriesName': 'Belgium tour of Austria 2025', 'matchInfo': [{'matchId': 132676, 'seriesId': 10746, 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1756020600000', 'endDate': '1756079999000', 'team1': {'teamId': 532, 'team
# ...

# %%
data
# Out:
# {'matchScheduleMap': [{'scheduleAdWrapper': {'date': 'SUN, AUG 24 2025',
#     'matchScheduleList': [{'seriesName': 'South Africa tour of Australia, 2025',
#       'matchInfo': [{'matchId': 117020,
#         'seriesId': 9602,
#         'matchDesc': '3rd ODI',
#         'matchFormat': 'ODI',
#         'startDate': '1756009800000',
#         'endDate': '1756079999000',
#         'team1': {'teamId': 4,
#          'teamName': 'Australia',
#          'teamSName': 'AUS',
#          'isFullMember': True,
#          'imageId': 172117},
#         'team2': {'teamId': 11,
#          'teamName': 'South Africa',
#          'teamSName': 'RSA',
#          'isFullMember': True,
#          'imageId': 172126},
#         'venueInfo': {'ground': 'Great Barrier Reef Arena',
#          'city': 'Mackay',
#          'country': 'Australia',
#          'timezone': '+10:00'},
#         'isFantasyHandbookEnabled': True}],
#       'seriesId': 9602,
#       'seriesCategory': 'International',
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['matchScheduleMap', 'startDt', 'appIndex'])

# %%
data['matchScheduleMap']
# Out:
# [{'scheduleAdWrapper': {'date': 'SUN, AUG 24 2025',
#    'matchScheduleList': [{'seriesName': 'South Africa tour of Australia, 2025',
#      'matchInfo': [{'matchId': 117020,
#        'seriesId': 9602,
#        'matchDesc': '3rd ODI',
#        'matchFormat': 'ODI',
#        'startDate': '1756009800000',
#        'endDate': '1756079999000',
#        'team1': {'teamId': 4,
#         'teamName': 'Australia',
#         'teamSName': 'AUS',
#         'isFullMember': True,
#         'imageId': 172117},
#        'team2': {'teamId': 11,
#         'teamName': 'South Africa',
#         'teamSName': 'RSA',
#         'isFullMember': True,
#         'imageId': 172126},
#        'venueInfo': {'ground': 'Great Barrier Reef Arena',
#         'city': 'Mackay',
#         'country': 'Australia',
#         'timezone': '+10:00'},
#        'isFantasyHandbookEnabled': True}],
#      'seriesId': 9602,
#      'seriesCategory': 'International',
#      'isFantasyEnabled': True},
# ...

# %%
data['appIndex']
# Out:
# {'seoTitle': 'Cricket Schedule - International, domestic and T20 matches - Cricbuzz',
#  'webURL': 'www.cricbuzz.com/cricket-schedule/series'}

# %%
data['startDt']
# Out:
# ['1756009800000',
#  '1756020600000',
#  '1756036800000',
#  '1756306800000',
#  '1756452600000',
#  '1756479600000',
#  '1756479600000',
#  '1756450800000',
#  '1756465200000',
#  '1756467000000',
#  '1756483200000',
#  '1756566000000',
#  '1756555200000',
#  '1756533600000',
#  '1756546200000',
#  '1756558800000',
#  '1756548000000',
#  '1756566000000',
#  '1756625400000',
#  '1756652400000',
#  '1756623600000',
#  '1756640700000',
#  '1756634400000',
#  '1756652400000',
#  '1756738800000',
#  '1756728000000',
#  '1756814400000',
#  '1756825200000',
#  '1756825200000',
#  '1756899000000',
#  '1756900800000',
#  '1756987200000',
#  '1756998000000',
#  '1756998000000',
#  '1757084400000',
#  '1757158200000',
#  '1757170800000',
#  '1757152800000',
#  '1757169000000',
#  '1757239200000',
#  '1757244600000',
#  '1757257200000',
#  '1757239200000',
#  '1757255400000',
#  '1757426400000',
#  '1757525400000',
#  '1757512800000',
#  '1757599200000',
#  '1757698200000',
#  '1757685600000',
# ...

# %%
rows = []
for schedule in data.get("matchScheduleMap", []):
    wrapper = schedule.get("scheduleAdWrapper", {})
    for series in wrapper.get("matchScheduleList", []):
        series_name = series.get("seriesName")
        for match in series.get("matchInfo", []):
            row = {
                "Match ID": match.get("matchId"),
                "Match": match.get("matchDesc"),
                "Series": series_name,
                "Team 1": match.get("team1", {}).get("teamName"),
                "Team 2": match.get("team2", {}).get("teamName"),
                "Venue": match.get("venueInfo", {}).get("ground"),
                "City": match.get("venueInfo", {}).get("city"),
                "Start Date": match.get("startDate")
            }
            rows.append(row)

df = pd.DataFrame(rows)
df
# Out:
#     Match ID       Match                                     Series  \
# 0     117020     3rd ODI       South Africa tour of Australia, 2025
# 1     132676    3rd T20I               Belgium tour of Austria 2025
# 2     132681    4th T20I               Belgium tour of Austria 2025
# 3     128875  80th Match   ICC Cricket World Cup League Two 2023-27
# 4     133077   1st Match                    Eastern Europe Cup 2025
# 5     133083   2nd Match                    Eastern Europe Cup 2025
# 6     122940     1st ODI           Sri Lanka tour of Zimbabwe, 2025
# 7     133127   1st Match       Guernsey Tri-Nation T20I Series 2025
# 8     133132   2nd Match       Guernsey Tri-Nation T20I Series 2025
# 9     131037   1st Match  United Arab Emirates T20I Tri-Series 2025
# 10    128886  81st Match   ICC Cricket World Cup League Two 2023-27
# 11    133094   3rd Match                    Eastern Europe Cup 2025
# 12    133099   4th Match                    Eastern Europe Cup 2025
# ...

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/teams/v1/2/players"

headers = {
	"x-rapidapi-key": "5d1acd4318msh2a53e9ea9913af9p12e3f0jsn95bb880184c8",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
data=response.json()
print(response.json())
# Out:
# {'player': [{'name': 'BATSMEN', 'imageId': 174146}, {'id': '11808', 'name': 'Shubman Gill', 'imageId': 616515, 'battingStyle': 'Right-hand bat', 'bowlingStyle': 'Right-arm offbreak'}, {'id': '13940', 'name': 'Yashasvi Jaiswal', 'imageId': 591942, 'battingStyle': 'Left-hand bat', 'bowlingStyle': 'Right-arm legbreak'}, {'id': '13866', 'name': 'Sai Sudharsan', 'imageId': 717782, 'battingStyle': 'Left-hand bat', 'bowlingStyle': 'Right-arm legbreak'}, {'id': '576', 'name': 'Rohit Sharma', 'imageId': 616514, 'battingStyle': 'Right-hand bat', 'bowlingStyle': 'Right-arm offbreak'}, {'id': '1413', 'name': 'Virat Kohli', 'imageId': 616517, 'battingStyle': 'Right-hand bat', 'bowlingStyle': 'Right-arm medium'}, {'id': '7915', 'name': 'Suryakumar Yadav', 'imageId': 352481, 'battingStyle': 'Right-hand bat', 'bowlingStyle': 'Right-arm offbreak'}, {'id': '9428', 'name': 'Shreyas Iyer', 'imageId': 616518, 'battingStyle': 'Right-hand bat', 'bowlingStyle': 'Right-arm legbreak'}, {'id': '10896', 'name':
# ...

# %%
data.keys()
# Out:
# dict_keys(['players'])

# %%
players = data.get("player", [])

rows = []
for p in players:
    row = [
        p.get("id"),
        p.get("name"),
        p.get("role"),
        p.get("battingStyle"),
        p.get("bowlingStyle")
    ]
    rows.append(row)

# Create DataFrame
df = pd.DataFrame(rows, columns=["Player ID", "Name", "Role", "Batting Style", "Bowling Style"])
df
# Out:
#    Player ID                 Name  Role   Batting Style          Bowling Style
# 0       None              BATSMEN  None            None                   None
# 1      11808         Shubman Gill  None  Right-hand bat     Right-arm offbreak
# 2      13940     Yashasvi Jaiswal  None   Left-hand bat     Right-arm legbreak
# 3      13866        Sai Sudharsan  None   Left-hand bat     Right-arm legbreak
# 4        576         Rohit Sharma  None  Right-hand bat     Right-arm offbreak
# 5       1413          Virat Kohli  None  Right-hand bat       Right-arm medium
# 6       7915     Suryakumar Yadav  None  Right-hand bat     Right-arm offbreak
# 7       9428         Shreyas Iyer  None  Right-hand bat     Right-arm legbreak
# 8      10896          Rinku Singh  None   Left-hand bat     Right-arm offbreak
# 9      14504          Tilak Varma  None   Left-hand bat     Right-arm offbreak
# 10     11813      Ruturaj Gaikwad  None  Right-hand bat     Right-arm offbreak
# ...

# %%
import requests
import pandas as pd


url = "https://cricbuzz-cricket.p.rapidapi.com/series/v1/3641"

headers = {
	"x-rapidapi-key": "5d1acd4318msh2a53e9ea9913af9p12e3f0jsn95bb880184c8",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
data=response.json()
# Out:
# {'matchDetails': [{'matchDetailsMap': {'key': 'Fri, 20 May 2022 - Mon, 23 May 2022', 'match': [{'matchInfo': {'matchId': 48002, 'seriesId': 3641, 'seriesName': 'New Zealand tour of England, 2022', 'matchDesc': '1st Warm-up Match', 'matchFormat': 'TEST', 'startDate': '1653040800000', 'endDate': '1653300000000', 'state': 'complete', 'status': 'Match drawn', 'team1': {'teamId': 41, 'teamName': 'SUSSEX', 'teamSName': 'SUS', 'imageId': 172148}, 'team2': {'teamId': 13, 'teamName': 'NEW ZEALAND', 'teamSName': 'NZ', 'imageId': 172128}, 'venueInfo': {'ground': 'County Ground', 'city': 'Hove', 'timezone': '+01:00'}, 'curBatTeamId': 13, 'isTimeAnnounced': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 2, 'runs': 247, 'wickets': 10, 'overs': 79.1}}, 'team2Score': {'inngs1': {'inningsId': 1, 'runs': 342, 'wickets': 3, 'overs': 90.0, 'isDeclared': True}, 'inngs2': {'inningsId': 3, 'runs': 40, 'overs': 8.0}}}}], 'seriesId': 3641}}, {'adDetail': {'name': 'native_news_index_random_1', '
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['matchDetails', 'appIndex'])

# %%
data['matchDetails']
# Out:
# [{'matchDetailsMap': {'key': 'Fri, 20 May 2022 - Mon, 23 May 2022',
#    'match': [{'matchInfo': {'matchId': 48002,
#       'seriesId': 3641,
#       'seriesName': 'New Zealand tour of England, 2022',
#       'matchDesc': '1st Warm-up Match',
#       'matchFormat': 'TEST',
#       'startDate': '1653040800000',
#       'endDate': '1653300000000',
#       'state': 'complete',
#       'status': 'Match drawn',
#       'team1': {'teamId': 41,
#        'teamName': 'SUSSEX',
#        'teamSName': 'SUS',
#        'imageId': 172148},
#       'team2': {'teamId': 13,
#        'teamName': 'NEW ZEALAND',
#        'teamSName': 'NZ',
#        'imageId': 172128},
#       'venueInfo': {'ground': 'County Ground',
#        'city': 'Hove',
#        'timezone': '+01:00'},
#       'curBatTeamId': 13,
#       'isTimeAnnounced': True},
#      'matchScore': {'team1Score': {'inngs1': {'inningsId': 2,
#         'runs': 247,
#         'wickets': 10,
#         'overs': 79.1}},
# ...

# %%
data['appIndex']
# Out:
# {'seoTitle': 'New Zealand tour of England, 2022 live scores, schedule and results - Cricbuzz | Cricbuzz.com',
#  'webURL': 'www.cricbuzz.com/cricket-series/'}

# %%
def extract_matches(obj, matches_list):
    if isinstance(obj, dict):
        if "matchInfo" in obj:
            info = obj["matchInfo"]
            matches_list.append({
                "match_id": info.get("matchId"),
                "team1": info.get("team1", {}).get("teamName"),
                "team2": info.get("team2", {}).get("teamName"),
                "venue": info.get("venueInfo", {}).get("ground"),
                "city": info.get("venueInfo", {}).get("city"),
                "date": info.get("startDate")
            })
        # Recurse into dict values
        for v in obj.values():
            extract_matches(v, matches_list)
    elif isinstance(obj, list):
        for item in obj:
            extract_matches(item, matches_list)

matches_list = []
extract_matches(data, matches_list)

df = pd.DataFrame(matches_list)
df
# Out:
#    match_id                               team1        team2          venue  \
# 0     48002                              SUSSEX  NEW ZEALAND  County Ground
# 1     48009  PROFESSIONAL COUNTY CLUB SELECT XI  NEW ZEALAND  County Ground
# 2     38326                             ENGLAND  NEW ZEALAND         Lord's
# 3     38331                             ENGLAND  NEW ZEALAND   Trent Bridge
# 4     38332                             ENGLAND  NEW ZEALAND     Headingley
#
#          city           date
# 0        Hove  1653040800000
# 1  Chelmsford  1653559200000
# 2      London  1654164000000
# 3  Nottingham  1654855200000
# 4       Leeds  1655978400000

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/series/v1/3718/squads/15826"

headers = {
	"x-rapidapi-key": "5d1acd4318msh2a53e9ea9913af9p12e3f0jsn95bb880184c8",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
data=response.json()
print(response.json())
# Out:
# {'player': [{'name': 'BATTERS', 'isHeader': True}, {'id': '11172', 'name': 'Finn Allen', 'role': 'Batter', 'imageId': 594254, 'battingStyle': 'Right-hand bat'}, {'id': '14514', 'name': 'Troy Johnson', 'role': 'Batter', 'imageId': 174146, 'battingStyle': 'Right-hand bat', 'bowlingStyle': 'Right-arm offbreak'}, {'id': '15567', 'name': 'Nick Greenwood', 'role': 'Batter', 'imageId': 174146, 'battingStyle': 'Right-hand bat'}, {'id': '18567', 'name': 'James Hartshorn', 'role': 'Batter', 'imageId': 174146, 'battingStyle': 'Right-hand bat', 'bowlingStyle': 'Right-arm medium'}, {'name': 'ALL ROUNDERS', 'isHeader': True}, {'id': '9551', 'name': 'Michael Bracewell', 'captain': True, 'role': 'Batting Allrounder', 'imageId': 616430, 'battingStyle': 'Left-hand bat', 'bowlingStyle': 'Right-arm offbreak'}, {'id': '13364', 'name': 'Luke Georgeson', 'role': 'Batting Allrounder', 'imageId': 156010, 'battingStyle': 'Left-hand bat', 'bowlingStyle': 'Right-arm fast-medium'}, {'id': '10724', 'name': 'Jamie
# ...

# %%
data.keys()
# Out:
# dict_keys(['player'])

# %%
data['player']
# Out:
# [{'name': 'BATTERS', 'isHeader': True},
#  {'id': '11172',
#   'name': 'Finn Allen',
#   'role': 'Batter',
#   'imageId': 594254,
#   'battingStyle': 'Right-hand bat'},
#  {'id': '14514',
#   'name': 'Troy Johnson',
#   'role': 'Batter',
#   'imageId': 174146,
#   'battingStyle': 'Right-hand bat',
#   'bowlingStyle': 'Right-arm offbreak'},
#  {'id': '15567',
#   'name': 'Nick Greenwood',
#   'role': 'Batter',
#   'imageId': 174146,
#   'battingStyle': 'Right-hand bat'},
#  {'id': '18567',
#   'name': 'James Hartshorn',
#   'role': 'Batter',
#   'imageId': 174146,
#   'battingStyle': 'Right-hand bat',
#   'bowlingStyle': 'Right-arm medium'},
#  {'name': 'ALL ROUNDERS', 'isHeader': True},
#  {'id': '9551',
#   'name': 'Michael Bracewell',
#   'captain': True,
#   'role': 'Batting Allrounder',
#   'imageId': 616430,
#   'battingStyle': 'Left-hand bat',
#   'bowlingStyle': 'Right-arm offbreak'},
#  {'id': '13364',
#   'name': 'Luke Georgeson',
#   'role': 'Batting Allrounder',
# ...

# %%
players_list=[]
def walk_json(obj):
    if isinstance(obj, dict):
        # check if this dict looks like a player
        if "name" in obj and "role" in obj:
            players_list.append({
                "id": obj.get("id"),
                "name": obj.get("name"),
                "role": obj.get("role"),
                "batting_style": obj.get("battingStyle"),
                "bowling_style": obj.get("bowlingStyle")
            })
        # keep exploring
        for v in obj.values():
            walk_json(v)
    elif isinstance(obj, list):
        for item in obj:
            walk_json(item)

# extract all players
walk_json(data)

# convert to dataframe
df = pd.DataFrame(players_list)
df
# Out:
#        id                name                role   batting_style  \
# 0   11172          Finn Allen              Batter  Right-hand bat
# 1   14514        Troy Johnson              Batter  Right-hand bat
# 2   15567      Nick Greenwood              Batter  Right-hand bat
# 3   18567     James Hartshorn              Batter  Right-hand bat
# 4    9551   Michael Bracewell  Batting Allrounder   Left-hand bat
# 5   13364      Luke Georgeson  Batting Allrounder   Left-hand bat
# 6   10724        Jamie Gibson  Batting Allrounder  Right-hand bat
# 7   11177     Rachin Ravindra  Batting Allrounder   Left-hand bat
# 8   13362         Jakob Bhula  Batting Allrounder  Right-hand bat
# 9   11170        Nathan Smith  Bowling Allrounder  Right-hand bat
# 10  10717        Tom Blundell           WK-Batter  Right-hand bat
# 11  13366    Callum McLachlan           WK-Batter  Right-hand bat
# 12   9844         Ian McPeake              Bowler  Right-hand bat
# ...
